# %% [markdown]
# **Comentario del Revisor**
#
# Hola!
#
# Soy Juan Manuel Romero, pero siéntete libre de llamarme Juanma. Soy code reviewer en Tripleten y hoy estaré revisando tu entrega.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Solo un aviso rápido: cuando estés revisando el proyecto, por favor deja mis comentarios originales tal como están. De esta manera, podemos seguir fácilmente el progreso y asegurarnos de que no se nos pase nada por alto. Y, si realizas algún cambio basado en mis comentarios, sería genial si pudieras resaltar esas actualizaciones para que se destaquen.
#
# Puedes encontrar mis comentarios en cajas verdes, amarillas o rojas como estas:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Éxito. Todo se ha hecho correctamente.
#
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
#
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Requiere corrección. El bloque requiere algunas correcciones. El trabajo no puede ser aceptado con los comentarios en rojo.
#
# </div>
#
# Puedes responderme usando esto:
#
# <div class="alert alert-block alert-info"> <b>Respuesta del estudiante.</b> <a class="tocSkip"></a> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>COMENTARIO GENERAL #1</b> <a class="tocSkip"></a>
#
# Felicidades Pablo! Tu trabajo es excelente.
#
# Has completado todos los items necesarios para aprobar la entrega.
#
# Sigue así!
#
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
# importar librerías
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al separar la importación de bibliotecas de la carga de los datasets! Esto mejora la estructura y claridad de tu código.
#
# </div>

# %%
# leer conjuntos de datos en los DataFrames
df_instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
df_products = pd.read_csv('/datasets/products.csv', sep=';')
df_order_products = pd.read_csv('/datasets/order_products.csv',sep=';')
df_aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
df_departments = pd.read_csv('/datasets/departments.csv', sep=';')

# %%
# mostrar información del DataFrame aisles
df_aisles.info()
df_aisles.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# mostrar información del DataFrame departments
df_departments.info()
df_departments.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# mostrar información del DataFrame instacart_orders
df_instacart_orders.info()
df_instacart_orders.sample(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 306037   2274265    73835            37          3                 13
# 231582   1330656   194499            24          2                 17
# 354787   1126168   178129             2          0                 12
# 256895   1944211    21736             2          6                 14
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto! Es bueno incluir el parámetro `show_counts=True` al explorar el DataFrame `order_products`. Esto proporciona una visión más clara de los datos no nulos y es una buena práctica para datasets grandes.
#
# </div>

# %%
# mostrar información del DataFrame order_products
df_order_products.info(show_counts=True)
df_order_products.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#          order_id  product_id  add_to_cart_order  reordered
# 3981742    910157       20919                2.0          0
# 2509738    859101       45840                3.0          1
# 1656198    434347       44310                7.0          1
# 3262664   2250528       39850                8.0          1
# 1683138    363060        7304                6.0          1
# 3478436   2691817       49683               15.0          0
# 3742419   1558724       17122                8.0          0
# ...

# %%
# mostrar información del DataFrame products
df_products.info()
df_products.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#        product_id                                       product_name  \
# 30167       30168  Natural Vegetable Laxative Plus Stool Softener...
# 36875       36876                           Magnesium Citrate Cherry
# 31624       31625                                  Essence Tangerine
# 13738       13739                     Healing Baby Diaper Rash Cream
# 931           932                 Vegetable Pie In A Pocket Sandwich
# 8055         8056                             Berry Bounty Trail Mix
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Muy buen uso de métodos como _info_ y _head_ para la exploración de datos.
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
# del DF
# df_instacart_orders:
# *  days_ since prior_order es tipo float64 y debería ser int64, así como tiene valores vacíos. (es entendible que existan pedidos que no hayan transcurrido días desde el último pedido(nuevas compras). Considero que en caso de probar esta teoría no sería necesario hacer algo con los valores nulos en esta columna.
#
#
# df_order_products:
# *  add_to_cart_order es tipo float64 y en teoría representa el orden secuencial en el que se añadieron los productos al pedido, deberían ser valores enteros. me llama la atención que existan valores vacíos.
#
# df_products:
# *  me llama mucho la atención que 'product_name' tenga valores vacíos. ya que existen 49694 id de producto pero solamente hay 48436 nombres de producto no vacíos. SON 1,258 productos sin nombre!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al incluir conclusiones intermedias sobre la vista general de los datos
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# Los valores en las columnas 'ID' de todos los DF son int
#
# con base en los hallazgos del paso 1 considero importante corregir el tipo de datos:
# *  'days_since_prior_order' de float a int (decidir qué hacer con los Nan que son primeras compras.)
# *  'add_to_cart_order de float a int' y averiguar lo que son los NAN.
# *  Investigar los nombres de los productos faltantes en 'product_name'
#
#
# Valores duplicados:
# *  Utilizar duplicated() para verificar valores duplicados en las filas de los DF
# *  Eliminar valores duplicados

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados


print(df_instacart_orders.duplicated().sum())

df_instacart_orders[df_instacart_orders.duplicated(keep=False)].sort_values(by='user_id') #vemos cuales son los valores duplicados
# Out:
# 15
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 441599   2125197    14050            48          3                  2
# 204042   2125197    14050            48          3                  2
# 142258   2845099    31189            11          3                  2
# 284038   2845099    31189            11          3                  2
# 99462     794638    50898            24          3                  2
# 145574    794638    50898            24          3                  2
# 242618   1021560    53767             3          3                  2
# 311713   1021560    53767             3          3                  2
# 371905    391768    57671            19          3                  2
# 354993    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# 250626    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
# lo que tienen en común es que fueron el miercoles a las 2 am... son 15 filas duplicadas con esos criterios.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.

#son 15 duplicados y al imprimir las filas duplicadas junto con sus originales, se realizaron todos estos registros el día miércoles a las 2am


pedidos_miercoles_2am = df_instacart_orders[
    (df_instacart_orders['order_dow'] == 3) & 
    (df_instacart_orders['order_hour_of_day'] == 2)]


print(pedidos_miercoles_2am.duplicated().sum())
# Out:
# 15

# %% [markdown]
# ¿Qué sugiere este resultado?
# un error de sistema provocó que ciertos pedidos se duplicaran en ese horario.

# %%
# Elimina los pedidos duplicados
df_instacart_orders = df_instacart_orders.drop_duplicates().reset_index(drop=True)

# %%
# Vuelve a verificar si hay filas duplicadas
df_instacart_orders.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
df_instacart_orders['order_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al identificar los duplicados en `orders`, especialmente aquellos relacionados con pedidos realizados a las 2:00 AM los miércoles! También aplicaste `.reset_index(drop=True)` después de `.drop_duplicates()`, lo cual es una buena práctica.
#
# </div>

# %% [markdown]
# Los pedidos se duplicaron el día miércoles a las 2 am lo que sugiere una falla en el sistema que genero valores duplicados. Aquí si era duplicados reales.

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
df_products.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay ID de productos duplicados
df_products['product_id'].duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
print(df_products['product_name'].str.upper().duplicated().sum())

products_duplicados = (
    df_products['product_name']
    .str.upper()
    .duplicated(keep=False)
)


df_products.loc[products_duplicados, 'product_name'].unique()
# Out:
# 1361
# array([nan, 'Biotin 1000 mcg',
#        'Fresh Scent Dishwasher Detergent with Dawn',
#        'American Cheese Slices', 'Cauliflower head',
#        'NUTrition Protein Mix Blueberry Nut',
#        'Yams Cut Sweet Potatoes in Syrup',
#        'Pineapple Slices In Heavy Syrup',
#        'Green Tea with Ginseng and Honey', 'Biotin 1000 Mcg',
#        'Powerball Max in 1 Shine & Protect',
#        "Tender white meat chicken- vegetables & rice in a cheddar cheese sauce Grandma's Chicken & Vegetable Rice Bake",
#        'Bbq Sauce', 'Cinnamon Rolls With Icing',
#        "Potatoes O'Brien With Onions And Peppers",
#        'Bleu Cheese Salad Dressing and Dip', 'Beef Chili with Beans',
#        'Solid White Albacore Tuna In Water', 'Bag of Oranges',
#        'Vitamin D3 2000 IU', 'Mandarin Oranges In Light Syrup',
#        'Pumpkin Spice', 'Cream of Mushroom Soup',
#        'Green Tea With Ginseng and Honey', 'Cream Of Mushroom Soup',
#        'Cream Of Tartar', 'Half and Half',
# ...

# %%
# Revisa si hay nombres duplicados de productos no faltantes
productos_con_nombre = df_products.dropna(subset=['product_name'])  # DataFrame filtrado
duplicados_no_faltantes = productos_con_nombre['product_name'].str.upper().duplicated().sum()
print(duplicados_no_faltantes)
# Out:
# 104

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# como habíamos visto desde un inicio que había 1258 productos sin nombre, estos concuerdan mucho con que 1361 duplicados, 104 eran duplicados reales en la columna nombre.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# En este paso lo importante es detectar que hay productos con el mismo nombre, pero distintos ID's de producto. Probablemente son productos diferentes por lo que no se tratan como duplicados, luego, la tabla `products` no contiene realmente valores duplicados.
#
# Es importante que aclares en tu descripción que estos no son errores, sino que indican que varios productos pueden tener el mismo nombre, incluso si su `product_id` es único. Esto es un comportamiento normal en los datos de un negocio.
#
# Pero lo interesante es realizar este análisis.
#
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_departments.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
df_departments['department_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# no hay valores duplicados en el df de departments

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_aisles.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
df_aisles['aisle_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# no hay duplicados en el DF aisles. lo deje tal cual

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto, no hay duplicados en _departments_ ni en _aisles_.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_order_products.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
#sospecho que hay duplicados en los valores vacíos, podría ser una combinación de product_ con order_id 
#ya que podrían haber sido agregados productos sin add_to_cart_order (esta columna representa el órden de adición al pedido. estos sugieren un error)
duplicados_sospechosos = df_order_products[df_order_products.duplicated(subset=['order_id', 'product_id'], keep= False)]

print(duplicados_sospechosos.duplicated().sum()) #para ver si los duplicados de los que sospecho 
print(df_order_products.isnull().sum())
# Out:
# 0
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
print("Filas CON add_to_cart_order:")

df_order_products[df_order_products['add_to_cart_order'].notnull()].head(5)



print("\nFilas SIN add_to_cart_order (NA):")
df_order_products[df_order_products['add_to_cart_order'].isnull()].head(5)
# Out:
# Filas CON add_to_cart_order:
#
# Filas SIN add_to_cart_order (NA):
#        order_id  product_id  add_to_cart_order  reordered
# 737     2449164        5068                NaN          0
# 9926    1968313       43867                NaN          0
# 14394   2926893       11688                NaN          0
# 16418   1717990        4142                NaN          0
# 30114   1959075       42828                NaN          1

# %%
# Examinar productos con add_to_cart_order
pedidos_con_nan = df_order_products[df_order_products['add_to_cart_order'].isnull()]['order_id'].unique() #veamos cuales son 
print(f"Número de pedidos únicos con valores NaN: {len(pedidos_con_nan)}") #veamos cuantos son


# Mira un ejemplo completo de un pedido con NaN
ejemplo_pedido = pedidos_con_nan[0] #seleccionamos el primer producto que aparece con valores nan en add_to_cart_order
pedido_completo = df_order_products[df_order_products['order_id'] == ejemplo_pedido] #filtramos los productos que pertenecen al primer pedido en aparecer con valores nan en add_to_cart_order
print(pedido_completo)
# Out:
# Número de pedidos únicos con valores NaN: 70
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 128360    2449164       14386                NaN          0
# 187426    2449164       32864               10.0          1
# 193859    2449164        8518                NaN          0
# 234913    2449164       24497               32.0          1
# ...           ...         ...                ...        ...
# 4279508   2449164        7781               55.0          1
# 4335855   2449164       25295               54.0          1
# 4407623   2449164        4920                NaN          1
# 4423417   2449164       35912                NaN          0
# 4480899   2449164       47759               11.0          1
#
# [76 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Bien hecho al verificar duplicados en el subconjunto `['order_id', 'product_id']`! Esto asegura que cada producto esté correctamente asignado a un pedido.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Encontramos 836 productos en total sin add_to_cart_order, estos están concentrados en 70 order_id. ésto puede representar, un error de sistema, un agregado especial a la órden. realmente no tenemos suficiente información por lo que decidí dejarlos ya que realmente no afectan para el cálculo. Los eliminaría si el cliente me indicara que son valores problemáticos.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
df_products['product_name'].isna().sum()
# Out:
# 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# Como habíamos descubierto anteriormente, existen 1258 productos sin nombre.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
productos_sin_nombre = df_products[df_products['product_name'].isna()]
print(productos_sin_nombre['aisle_id'].unique())
# Out:
# [100]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# si, todos los productos ausentes están relacionados con el pasillo 100

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
print(productos_sin_nombre['department_id'].unique())
# Out:
# [21]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# Todos los valores sin nombre coinciden con el departamento con el id 21

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
pasillo_100 = df_aisles[df_aisles['aisle_id']==100]
departamento_21 = df_departments[df_departments['department_id']== 21]
print(departamento_21)
print(pasillo_100)
# Out:
#     department_id department
# 20             21    missing
#     aisle_id    aisle
# 99       100  missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# Tanto el nombre de departamento, como el nombre de pasillo en los productos sin nombres es 'missing', es decir, faltante...

# %%
# Completa los nombres de productos ausentes con 'Unknown'
df_products['product_name'] = df_products['product_name'].fillna('Unknown')

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Se imputó el valor unknown, para todos los desconocidos. me parece que es lo más lógico cuando no sabemos de qué se trata la información.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al identificar los valores ausentes en `product_name` y asociarlos con las columnas `aisle_id` y `department_id`! Reemplazar estos valores con `'Unknown'` es una decisión lógica y adecuada.
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
df_instacart_orders.isna().sum()
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
pedidos_ausentes = df_instacart_orders[df_instacart_orders['days_since_prior_order'].isna()]
print(pedidos_ausentes['order_number'].unique())
# Out:
# [1]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Confirmamos la sospecha de que son las primeras compras de cada cliente. de hecho al principio del proyecto hice un muestreo y los valores de algunos Nan coincidían con el 1 en order_number. por lo tanto no hay que modificar ni eliminar el valor.
#
# y también con esto podemos concluir que tenemos 28817 usuarios!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Identificaste correctamente que los valores ausentes en `days_since_prior_order` corresponden a `order_number == 1`! Dejar los valores como `NaN` o usar un valor razonable asegura que los datos se manejen correctamente.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
df_order_products.isna().sum()
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print('El valor mínimo es:')
print(df_order_products['add_to_cart_order'].min())
print('El valor máximo es:')
print(df_order_products['add_to_cart_order'].max())
# Out:
# El valor mínimo es:
# 1.0
# El valor máximo es:
# 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# 1 y 64 son los valores mínimo y máximos, pero previamente exploré un poco los datos y noté que hay un pedido con 76 productos... es sospechoso

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
pedidos_nan = df_order_products[df_order_products['add_to_cart_order'].isna()]['order_id'].unique() #es lo mismo que la variable pedidos_con_nan
print(pedidos_nan) #estos son los Id que tienen NaN en su columna 'add_to_cart_order'
# Out:
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.

        #Filtrar el DF y obtener todos los pedidos con valores Nan
pedidos_con_nan_completos = df_order_products[df_order_products['order_id'].isin(pedidos_nan)]
        #Agrupar por 'order_id'
conteo_productos_nan = pedidos_con_nan_completos.groupby('order_id').size()

print(conteo_productos_nan.min())
print(conteo_productos_nan.max())
# Out:
# 65
# 127

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# los 70 pedidos que tienen los valores NaN en 'add_to_cart_order' tienen más de 64 productos. es posible que al exceder esa cantidad, el sistema los deje de registrar y se agreguen como Nan. no hay que eliminar esos valores.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].fillna(999) 
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].astype(int)
df_order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 138.7 MB

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# La imputación de los valores de la columna add_to_cart_number que excedían de 64 se realizó con el valor 999 para evitar la pérdida de datos y poder cambiar la columna a Int. Cuando tiene valores Nan automáticamente se pasa a float. ésto nos permitió cambiar a Int

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo!
#
# Un valor mínimo de 1 tiene sentido porque cada pedido necesita, al menos, 1 artículo. Pero, un valor máximo de 64 resulta un tanto curioso. No hay ninguna razón (que no sea mera suerte) para que cualquiera pidiera más de 64 artículos en un pedido.
#
# Además, 64 enciende las alarmas porque es un número de base 2 muy común que surgen con asuntos de informática. Esta es una pista de que quizás el tipo database para esa columna solo admite almacenamiento de 64 bits.
#
# Luego, como era de esperarse, cada pedido relacionado con un valor ausente tiene más de 64 artículos en ella.
#
# Ya que no podemos saber en qué pedido se agregaron al carrito los artículos con valores ausentes para aquellos pedidos con más de 65 artículos, lo correcto es completar los valores ausentes con un valor de marcador de posición numérico que no pueda confundirse con daros reales; por ejemplo, 999.
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
# Limpiamos posibles fallas de sistema (registros del df_instacart_orders)
#
# los productos sin nombre se catalogan en pasillo y departamento 'missing', se depuraron y se cambiaron el nombre a unknown, hay mucho error en la captura de información, probablemente tambien sean productos descontinuados.
#
# El sistema solo reporta 64 artículos en orden consecutivo en sus órdenes.
#
# los valores faltantes en 'days_since_prior_order' corresponden a primera compra y con eso podemos concluir que tenemos 28817 usuarios!

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
hora_mínima = df_instacart_orders['order_hour_of_day'].min()
hora_máxima = df_instacart_orders['order_hour_of_day'].max()

print(f'Las horas oscilan entre {hora_mínima} y {hora_máxima}')
# Out:
# Las horas oscilan entre 0 y 23

# %%
día_inicial = df_instacart_orders['order_dow'].min()
día_final = df_instacart_orders['order_dow'].max()
print(f'Los valores de día oscilan entre {día_inicial} y {día_final}')
# Out:
# Los valores de día oscilan entre 0 y 6

# %% [markdown]
# Escribe aquí tus conclusiones
# El formato de horas está en 24 y los días de 0 a 6 (domingo a lúnes)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Aquí sería mejor utilizar _value_counts_ para ver los valores únicos. Luego, puedes ordenar los resultados y comentar tus observaciones.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
from matplotlib import pyplot as plt
personas_por_hora = df_instacart_orders.groupby('order_hour_of_day')['user_id'].nunique()
personas_por_hora.plot(title= 'Numero de personas que hacen pedidos por hora del día',
                     kind='bar')
plt.xlabel('Hora del día')
plt.ylabel('Número de personas')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# La gente hace más pedidos durante las horas principales de actividad del día.
# son horarios asociados a la actividad, concuerda con los horarios de trabajo.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al usar un gráfico de barras para visualizar los datos! Además, la comunicación de los resultados es clara y precisa: identificaste correctamente que la mayoría de los pedidos ocurren entre las 9:00 AM y las 5:00 PM, con picos a las 10:00 AM y las 3:00 PM. Esto proporciona una gran perspectiva sobre el comportamiento del cliente.
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
día_de_compra = df_instacart_orders.groupby('order_dow')['user_id'].nunique()
día_de_compra.plot(kind='bar', title= 'Día de la semana que las personas realizan sus compras')
plt.xlabel('Día de la semana')
plt.ylabel('Número de personas')
# Out:
# Text(0, 0.5, 'Número de personas')

# %% [markdown]
# Escribe aquí tus conclusiones
# A la gente no le gusta salir de compras los domingos, los usuarios de Instacart prefieren dedicar sus fines de semana a otras actividades que perder su domingo en salir de su casa a hacer super. igualmente los lunes son días en los cuales compran la comida que utilizarán para cocinar durante la semana.
#
# los días entre semana tienen menos cantidad de personas haciendo pedidos, el cliente ideal de instacart es un planificador.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# El uso de un gráfico de barras para representar los datos es acertado y ayuda a visualizar las tendencias claramente. Tu comunicación de resultados también es precisa: identificaste correctamente que, asumiendo que el domingo es 0, la mayoría de los pedidos se realizan el domingo y el lunes.
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
orders_with_prior = df_instacart_orders.dropna(subset=['days_since_prior_order'])

orders_with_prior['days_since_prior_order'].plot(kind='hist', bins=30)
plt.xlabel('Días desde el pedido anterior')
plt.ylabel('Frecuencia')
plt.title('Distribución del tiempo entre pedidos (recompras)')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# la mayoría de los clientes hacen su recompra después de un mes pero también hay otro grupo que recompra casi cada semana.
#
# el cliente de instacart definitivamente es planificador.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al visualizar los datos!
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
#distribución de los días miércoles
miercoles = df_instacart_orders[df_instacart_orders['order_dow'] == 3]
miercoles_hora = miercoles.groupby('order_hour_of_day')['order_id'].count()
print(miercoles.count())
# Out:
# order_id                  60897
# user_id                   60897
# order_number              60897
# order_dow                 60897
# order_hour_of_day         60897
# days_since_prior_order    57271
# dtype: int64

# %%
#distribución de los sábados
sabados = df_instacart_orders[df_instacart_orders['order_dow'] == 6]
sabados_hora = sabados.groupby('order_hour_of_day')['order_id'].count()

# %%
miercoles_hora.plot(kind='bar',color='blue', )
sabados_hora.plot(kind='bar', color ='orange', alpha= 0.6)
plt.title('Distribución de pedidos por hora días miércoles y sábado')
plt.legend(['miércoles','sábado'])
plt.xlabel('Hora del día')
plt.ylabel('Cantidad de pedidos')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Identificaste correctamente una ligera disminución entre las 11h y las 13h los miércoles, que está ausente los sábados.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# los días sábados la gente hace más pedidos entre las 11 y las 5pm me imagino que lo hacen así por si salen por la noche, esperan tener sus productos ya en casa en el transcurso de la tarde.
# los miércoles la gente hace más pedidos entre las 6 y 7 am, posiblemente antes de entrar a trabajar. los pedidos 9 y 10 am coinciden con el inicio de una jornada laboral, probablemente los hacen al llegar al trabajo. y entre las 17 a 20 horas.
#
# las diferencias entre ambos se encuentran en que los sábados se hacen más pedidos a medio día y por la tarde y los miércoles por la mañana y por la noche.

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
distribución_pedidos = df_instacart_orders.groupby('user_id')['order_number'].count()

frecuencia_pedidos = distribución_pedidos.value_counts().sort_index()

# %%
frecuencia_pedidos.plot(kind='bar', title='Distribución del número de pedidos por cliente',
                      xlabel='Número de pedidos',
                      ylabel='Número de clientes',
                        figsize=(12,6)
                      )
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# Es esperable que la mayor cantidad de clientes hagan unos pocos pedidos,
# son muy pocos los usuarios que son realmente cautivos. probablemente estaría interesante incluír algunas notificaciones push con algúnu incentivo. o algún programa de recomensas estaría interesante implementarlo, podría servir como estrategia de gameficication.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Puede que un histograma sea más adecuado en este caso. Un histograma es adecuado cuando se desea analizar la distribución de un conjunto de datos continuos, es decir, aquellos que pueden tomar cualquier valor dentro de un rango. Se utiliza para representar la frecuencia con la que ocurren ciertos valores dentro de intervalos o clases, permitiendo identificar patrones como la simetría, la dispersión o la presencia de sesgos en los datos. Es especialmente útil en estadística para entender cómo se distribuyen variables como alturas, edades, tiempos de espera o calificaciones en un examen. A diferencia del gráfico de barras, en el histograma las barras están juntas, ya que los datos representados son continuos y no categorías separadas.
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
productos_mas_pedidos = df_order_products.groupby('product_id').size().sort_values(ascending=False).head(20)
print(productos_mas_pedidos) #la lista de los id de los productos más pedidos con la cantidad en la que se pidieron.
# Out:
# product_id
# 24852    66050
# 13176    53297
# 21137    37039
# 21903    33971
# 47209    29773
# 47766    24689
# 47626    21495
# 16797    20018
# 26209    19690
# 27845    19600
# 27966    19197
# 22935    15898
# 24964    15292
# 45007    14584
# 39275    13879
# 49683    13675
# 28204    12544
# 5876     12232
# 8277     11993
# 40706    11781
# dtype: int64

# %%
top_20_df = productos_mas_pedidos.reset_index() #asignamos índice de nuevo al series
top_20_df.columns =['product_id', 'cantidad'] #asignamos nombre de columna a product id y cantidad de veces que se pidió
#merge
resultado = top_20_df.merge(df_products, on='product_id') #
print(resultado)
# Out:
#     product_id  cantidad              product_name  aisle_id  department_id
# 0        24852     66050                    Banana        24              4
# 1        13176     53297    Bag of Organic Bananas        24              4
# 2        21137     37039      Organic Strawberries        24              4
# 3        21903     33971      Organic Baby Spinach       123              4
# 4        47209     29773      Organic Hass Avocado        24              4
# 5        47766     24689           Organic Avocado        24              4
# 6        47626     21495               Large Lemon        24              4
# 7        16797     20018              Strawberries        24              4
# 8        26209     19690                     Limes        24              4
# 9        27845     19600        Organic Whole Milk        84             16
# 10       27966     19197       Organic Raspberries       123              4
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto! Los productos populares se listan correctamente. Sin duda las bananas y los productos orgánicos en general son los "populares".
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# En el análisis de productos más populares ([B3]), sería útil añadir una visualización tipo gráfico de barras para complementar la tabla y facilitar una lectura rápida del ranking. Esto también permitiría detectar patrones visuales como posibles productos muy por encima del resto.
#
# </div>
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# los productos más solicitados son perecederos  y casí en su totalidad son productos orgánicos.
# significa que el usuario ideal es planificador y cuida su alimentación.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
cantidad_por_pedido = df_order_products.groupby('order_id').size()
print(cantidad_por_pedido.describe())
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# dtype: float64

# %%
veces_moda = (cantidad_por_pedido == 5).sum()
total_pedidos = len(cantidad_por_pedido)
porcentaje_moda = (veces_moda/total_pedidos) *100
pedidos_0_a_5 = cantidad_por_pedido[cantidad_por_pedido<=5]
porcentaje_0_a_5 = (len(pedidos_0_a_5)/ len(cantidad_por_pedido))*100
pedidos_5_a_10 = cantidad_por_pedido[(cantidad_por_pedido >5)&(cantidad_por_pedido <= 10)]
porcentaje_5_a_10 = (len(pedidos_5_a_10) / len(cantidad_por_pedido))*100
pedidos_10_a_15 = cantidad_por_pedido[(cantidad_por_pedido > 10) & (cantidad_por_pedido <= 15)]
porcentaje_10_a_15 = (len(pedidos_10_a_15)/len(cantidad_por_pedido))*100
suma_de_valores_porcentajes = porcentaje_0_a_5 + porcentaje_5_a_10 + porcentaje_10_a_15

print(f'El valor mínimo es de {cantidad_por_pedido.min()} y el valor máximo es de {cantidad_por_pedido.max()}')
print(f'La media es de: {cantidad_por_pedido.mean():.2f}')
print(f'la mediana es de: {cantidad_por_pedido.median()}')
print(f'la moda es: {cantidad_por_pedido.mode().iloc[0]}')
print(f'La moda se repite: {veces_moda}')
print(f'La valor de la moda representa el {porcentaje_moda:.2f}% de todos los pedidos')
print(f'El porcentaje de pedidos entre 0-5 productos: {porcentaje_0_a_5:.2f}%')
print(f'El porcentaje de pedidos entre 5-10 productos: {porcentaje_5_a_10:.2f}%')
print(f'El porcentaje de pedidos entre 5-10 productos: {porcentaje_10_a_15:.2f}%')
print(f'La suma de estos tres grupos es: {suma_de_valores_porcentajes:.2f}%')
# Out:
# El valor mínimo es de 1 y el valor máximo es de 127
# La media es de: 10.10
# la mediana es de: 8.0
# la moda es: 5
# La moda se repite: 31923
# La valor de la moda representa el 7.09% de todos los pedidos
# El porcentaje de pedidos entre 0-5 productos: 31.14%
# El porcentaje de pedidos entre 5-10 productos: 31.12%
# El porcentaje de pedidos entre 5-10 productos: 18.36%
# La suma de estos tres grupos es: 80.62%

# %%
plt.figure(figsize=(10, 6))
plt.hist(cantidad_por_pedido, bins=30)
plt.xlabel('Cantidad de productos por pedido')
plt.ylabel('Frecuencia')
plt.title('Distribución de productos por pedido')
plt.xticks(range(0, cantidad_por_pedido.max()+1,5))
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# A simple vista en el gráfico vemos que el pico principal corresponde a compras de 5 productos o menos
# el 50% de los usuarios pide 8 productos o menos.
# el promedio de productos por pedido es de 10%. los valores de la media jalan hacia arriba a los valores de la mediana debido a los pedidos extensos como lo vimos cuando analizamos que hay pedidos con más de 64 productos.
# la moda es de 5, significa que el valor más repetido es de 5 productos por pedido pero sólo representa un 7% de los valores, nuestra distribución está muy dispersa.
# Analizando los valores obtenidos tenemos entre que un porcentaje significativo hace pedidos entre 0 y 5 productos, el grupo de pedidos entre 5 y 10 productos es de 31.12% y el tercer grupo es de 18.35%.
#
# la mayoría de los clientes están concentrados ente 1 y 15 productos por pedido (el 80.62%)
# La mayoría de los pedidos son entre pequeños y medianos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo! Efectivamente vemos que las personas generalmente realizan pedidos de entre 1 y 10 artículos.
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
 #buscar los productos reordenados
productos_reordenados = df_order_products[df_order_products['reordered']==1]

# %%
#contar cuántas veces se ha reordenado
top_20_reordenados = productos_reordenados.groupby('product_id').size().sort_values(ascending=False).head(20)
print(top_20_reordenados)
# Out:
# product_id
# 24852    55763
# 13176    44450
# 21137    28639
# 21903    26233
# 47209    23629
# 47766    18743
# 27845    16251
# 47626    15044
# 27966    14748
# 16797    13945
# 26209    13327
# 22935    11145
# 24964    10411
# 45007    10076
# 49683     9538
# 28204     8989
# 8277      8836
# 39275     8799
# 5876      8412
# 49235     8389
# dtype: int64

# %%
top_20_reordenados = top_20_reordenados.reset_index() #se parece a lo que hicimos en B3
top_20_reordenados.columns=['product_id','cantidad'] #renombramos columnas
#merge de nuevo:
resultado_reordenados = top_20_reordenados.merge(df_products, on='product_id')
print(resultado_reordenados)
# Out:
#     product_id  cantidad              product_name  aisle_id  department_id
# 0        24852     55763                    Banana        24              4
# 1        13176     44450    Bag of Organic Bananas        24              4
# 2        21137     28639      Organic Strawberries        24              4
# 3        21903     26233      Organic Baby Spinach       123              4
# 4        47209     23629      Organic Hass Avocado        24              4
# 5        47766     18743           Organic Avocado        24              4
# 6        27845     16251        Organic Whole Milk        84             16
# 7        47626     15044               Large Lemon        24              4
# 8        27966     14748       Organic Raspberries       123              4
# 9        16797     13945              Strawberries        24              4
# 10       26209     13327                     Limes        24              4
# ...

# %%
#me interesa compararla con la tabla de los valores más populares. 
# Renombrar en resultado
resultado_renamed = resultado.rename(columns={'cantidad': 'cantidad_popular'})

# Renombrar en resultado_reordenados  
resultado_reordenados_renamed = resultado_reordenados.rename(columns={'cantidad': 'cantidad_reordenados'})

comparacion = resultado_renamed.merge(resultado_reordenados_renamed, on='product_id',how='outer')
# Seleccionar solo las columnas importantes
comparacion_limpia = comparacion[['product_id', 'product_name_x', 'cantidad_popular', 'cantidad_reordenados']].copy()
comparacion_limpia.columns = ['product_id', 'product_name', 'cantidad_popular', 'cantidad_reordenados']

# Gráfico de barras comparativo
comparacion_limpia.plot(x='product_name', y=['cantidad_popular', 'cantidad_reordenados'], 
                       kind='bar', figsize=(15, 8))
# Out:
# <AxesSubplot:xlabel='product_name'>

# %% [markdown]
# Escribe aquí tus conclusiones
# Los productos más pedidos son prácticamente los mismos que los productos con mayor recompra, tiene mucho sentido ya que se compran con mayor frecuencia.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Impecable, los resultados sobre los productos que vuelven a pedirse con mayor frecuenciason los esperados. Los plátanos siguen dominando.
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
# Primero, calculamos las estadísticas para todos los productos
reorder_by_product = df_order_products.groupby('product_id').agg({
    'reordered': ['sum', 'count']
}).reset_index()

# Aplanar las columnas
reorder_by_product.columns = ['product_id', 'sum', 'count']

# Calcular la proporción de recompra (sin filtrar por NaN)
reorder_by_product['reorder_proportion'] = reorder_by_product['sum'] / reorder_by_product['count']

# Ver las primeras filas
print(f"Total de productos analizados: {len(reorder_by_product)}")
reorder_by_product.head()

# Agregar nombres de productos
tabla_completa = reorder_by_product.merge(df_products[['product_id', 'product_name']], on='product_id')

# Renombrar columnas para que se vea mejor
tabla_completa = tabla_completa.rename(columns={
    'sum': 'total_recompras',
    'count': 'total_pedidos',
    'reorder_proportion': 'tasa_recompra'
})
print(tabla_completa.head(20))
# Out:
# Total de productos analizados: 45573
#     product_id  total_recompras  total_pedidos  tasa_recompra  \
# 0            1              158            280       0.564286
# 1            2                0             11       0.000000
# 2            3               31             42       0.738095
# 3            4               25             49       0.510204
# 4            7                1              2       0.500000
# 5            8                6             19       0.315789
# 6            9               16             21       0.761905
# 7           10              151            337       0.448071
# 8           11               10             16       0.625000
# 9           12               16             41       0.390244
# 10          13                1              2       0.500000
# 11          14                0              3       0.000000
# 12          17                0              1       0.000000
# ...

# %%
#tambien quiero analizar sobre los valores ya obtenidos antes de los productos con más ventas:
proporcion_simple = resultado_reordenados['cantidad'] / resultado['cantidad']
# Crear un DataFrame con los resultados
proporcion_con_nombres = pd.DataFrame({
    'product_id': resultado['product_id'],
    'product_name': resultado['product_name'],
    'total_pedidos': resultado['cantidad'],
    'recompras': resultado_reordenados['cantidad'],
    'proporcion_recompra': proporcion_simple
})

# %%
# Ordenar por mayor proporción de recompra
proporcion_con_nombres_ordenado = proporcion_con_nombres.sort_values(
    'proporcion_recompra', 
    ascending=False
)

print("Productos con mayor proporción de recompra:")
# Solo mostrar las columnas importantes
proporcion_limpia = proporcion_con_nombres_ordenado[['product_name', 'proporcion_recompra']].copy()
print("Top 10 productos con mayor proporción de recompra:")
print(proporcion_limpia.head(10))
# Out:
# Productos con mayor proporción de recompra:
# Top 10 productos con mayor proporción de recompra:
#               product_name  proporcion_recompra
# 0                   Banana             0.844254
# 1   Bag of Organic Bananas             0.834006
# 4     Organic Hass Avocado             0.793639
# 2     Organic Strawberries             0.773212
# 3     Organic Baby Spinach             0.772217
# 5          Organic Avocado             0.759164
# 6              Large Lemon             0.756036
# 7             Strawberries             0.751524
# 8                    Limes             0.749010
# 17           Organic Lemon             0.719343

# %% [markdown]
# Escribe aquí tus conclusiones
# Los productos con mayor recompra tienen una tasa entre el 70 y 84%

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
# Ver las columnas de cada DataFrame
print("Columnas en df_order_products:")
print(df_order_products.columns.tolist())

print("\nColumnas en df_instacart_orders:")
print(df_instacart_orders.columns.tolist())
# Out:
# Columnas en df_order_products:
# ['order_id', 'product_id', 'add_to_cart_order', 'reordered']
#
# Columnas en df_instacart_orders:
# ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
# Unir las dos tablas para saber qué cliente hizo cada pedido
datos_completos = df_order_products.merge(df_instacart_orders, on='order_id')

# Ver columnas actuales
print("Ahora tenemos las siguientes columnas:")
print(datos_completos.columns.tolist())
# Out:
# Ahora tenemos las siguientes columnas:
# ['order_id', 'product_id', 'add_to_cart_order', 'reordered', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
# Para cada cliente, contar recompras y total
por_cliente = datos_completos.groupby('user_id')['reordered'].agg(['sum', 'count'])
por_cliente.columns = ['recompras', 'total']
por_cliente['proporcion'] = por_cliente['recompras'] / por_cliente['total']

print(por_cliente.head(20))
# Out:
#          recompras  total  proporcion
# user_id
# 2                1     26    0.038462
# 4                0      2    0.000000
# 5                8     12    0.666667
# 6                0      4    0.000000
# 7               13     14    0.928571
# 11               3     15    0.200000
# 12               3     12    0.250000
# 13              13     23    0.565217
# 14              22     61    0.360656
# 15               7     13    0.538462
# 16              17     32    0.531250
# 17              38     53    0.716981
# 19              14     48    0.291667
# 20               0      4    0.000000
# 21               8     20    0.400000
# 22               6      6    1.000000
# 24               1      2    0.500000
# 26               7     16    0.437500
# 27              56     85    0.658824
# 28              22     44    0.500000

# %%
import matplotlib.pyplot as plt

# Crear histograma de las proporciones de recompra por cliente
plt.figure(figsize=(10, 6))
plt.hist(por_cliente['proporcion'], bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('Proporción de productos reordenados')
plt.ylabel('Número de clientes')
plt.title('Distribución de la proporción de recompra por cliente')
plt.grid(True, alpha=0.3)
plt.show()

# También puedes mostrar estadísticas descriptivas
print("Estadísticas de proporción de recompra por cliente:")
print(por_cliente['proporcion'].describe())
# Out:
# Estadísticas de proporción de recompra por cliente:
# count    149626.000000
# mean          0.494853
# std           0.292685
# min           0.000000
# 25%           0.272727
# 50%           0.500000
# 75%           0.724138
# max           1.000000
# Name: proporcion, dtype: float64

# %% [markdown]
# Escribe aquí tus conclusiones
#
#
# Por como observamos la distribución de la proporción tiene una mediana del 50% y su media es de 49.4% lo que nos podría dar una referencia de que para el 50% de los clientes la mitad de los productos que compran los vuelven a comprar.
#
# la otra mitad puede ser que experimenten con productos nuevos. mi sospecha es que los productos más vendidos son los que los clientes suelen recomprar.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo. Los resultados son los esperados.
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
# Filtrar productos que fueron agregados primero al carrito

primeros_productos = df_order_products[df_order_products['add_to_cart_order']==1]
# Contar cuántas veces cada producto fue puesto primero

top_20_primeros = primeros_productos.groupby('product_id').size().sort_values(ascending=False).head(20)
# Convertir a DataFrame y agregar nombres
top_20_primeros_df = top_20_primeros.reset_index()

top_20_primeros_df.columns = ['product_id', 'veces_primero']

# Merge con productos para obtener nombres

resultado_primeros = top_20_primeros_df.merge(df_products, on='product_id')

print('Top 20 productos que se ponen primero en el carrito:')

print(resultado_primeros[['product_name', 'veces_primero']])
# Out:
# Top 20 productos que se ponen primero en el carrito:
#                    product_name  veces_primero
# 0                        Banana          15562
# 1        Bag of Organic Bananas          11026
# 2            Organic Whole Milk           4363
# 3          Organic Strawberries           3946
# 4          Organic Hass Avocado           3390
# 5          Organic Baby Spinach           3336
# 6               Organic Avocado           3044
# 7                  Spring Water           2336
# 8                  Strawberries           2308
# 9           Organic Raspberries           2024
# 10   Sparkling Water Grapefruit           1914
# 11          Organic Half & Half           1797
# 12                  Large Lemon           1737
# 13                         Soda           1733
# 14     Organic Reduced Fat Milk           1397
# 15                        Limes           1370
# 16                Hass Avocados           1340
# 17  Organic Reduced Fat 2% Milk           1310
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Los 20 principales artículos que las personas ponen primero en sus carritos se listan correctamente y los conteos son los esperados. Se ve una tendencia por comenzar por los plátanos y productos orgánicos.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# se parecen mucho a los productos más populas en recompra, así como a los más populares.

# %% [markdown]
# ### Conclusion general del proyecto:
#
# los productos perecederos, organicos son los productos que los usuarios más compran y tambien tienen una recompra mayor. al ser los productos con mayor recompra estaría interesante que los clientes pudieran elegir nuevamente sus productos más comprados de una forma fácil. probablemente eso incentivaría más compras.
# los productos de mayor consumo y que la gente compra primero son: bananas, leche, aguacates y fresas.
#
# También considero que al ser perecederos la mayor parte de los productos y tener información de los días desde la última compra, el sistema podría enviar notificaciones push para recomprar, lo que podría incentivar la fidelidad de los usuarios.
#
# También en cuestión a la pauta publicitaría me centraría en un target que sea planificador y con estilo de vida saludable ya que el cliente ideal compra productos orgánicos. segmentar los anuncios a personas que sigan cuentas de ccontenido sobre como alimentarse de forma saludable.
#
# También consideraría que los días en los que hay pocos pedidos podríamos enviar notificaciones que inviten a revisar la alacena, para aquellos usuarios que no son tan recurrentes. tal vez una notificación a los 15 días de no recibir un pedido estaría prudente para no acosar a los usuarios.
